# %%
#Bivariate - numerical
import matplotlib.pyplot as plt
import pandas as pd

d1 = {
    "Sal" :[23000,45000,26000,56000,27000,45000,67000,70000],
    "Dept":["HR","Teacher","Fiance","HR","IT","IT","HR","Teacher"],
    "Age":[22,34,22,53,33,67,78,79]
}

# %%
d2 = pd.DataFrame(d1)

# %%
d2
# Out:
#      Sal     Dept  Age
# 0  23000       HR   22
# 1  45000  Teacher   34
# 2  26000   Fiance   22
# 3  56000       HR   53
# 4  27000       IT   33
# 5  45000       IT   67
# 6  67000       HR   78
# 7  70000  Teacher   79

# %%
d2.head()
# Out:
#      Sal     Dept  Age
# 0  23000       HR   22
# 1  45000  Teacher   34
# 2  26000   Fiance   22
# 3  56000       HR   53
# 4  27000       IT   33

# %%
d2
# Out:
#      Sal     Dept  Age
# 0  23000       HR   22
# 1  45000  Teacher   34
# 2  26000   Fiance   22
# 3  56000       HR   53
# 4  27000       IT   33
# 5  45000       IT   67
# 6  67000       HR   78
# 7  70000  Teacher   79

# %%
#scatter plot
plt.scatter(d2["Age"],d2["Sal"],color ="orange")
plt.show()

# %%
#line plt

plt.plot(d2["Age"],d2["Sal"],color = "red",marker = "*",linewidth = "2")
plt.show()

# %%
#bar cahrt

# %%
plt.bar(d2["Age"],d2["Sal"],color = "green") # color ,align
plt.show()
