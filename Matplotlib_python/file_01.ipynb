# %%
import matplotlib.pyplot as plt
# import pandas as pd

# %%
x = [1,2,3]
y =[4,5,6]
plt.plot(x,y)
plt.grid()
plt.show()

# %%
plt.grid()

# %%
plt.plot()
# Out:
# []

# %%
x =[2,4,6,6.7,8.9]
y =[4,6,8.5,2,4.5]
plt.plot(x,y)
plt.show()

# %%
plt.plot([1,2,3,4],[10,20,30,15])
plt.grid()
plt.show()

# %%
plt.plot([1,2,3,4], [10,20,15,30])
plt.grid(axis='x')
plt.show()

# %%
plt.plot([1,2,3,4], [10,20,15,30])
plt.grid(axis='y')
plt.show()

# %%
plt.plot([1,2,3,4], [10,20,15,30])
plt.grid(color='red', linestyle='--', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[10,20,30])
plt.xlabel("Days")
plt.ylabel("Sales")
plt.title("Daily Sales Report")
plt.grid()
plt.show()
