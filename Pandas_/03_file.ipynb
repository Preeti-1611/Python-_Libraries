# %%
#dataframe
import pandas as pd
import numpy as np
data = {
    'Name': ["preeti","bob","Me","Eve","adu"],
    'age':[23,30,35,np.nan,20],
    'dept':['HR','IT','finace','It',"HR"],
    'sal':[23000,45000,70000,np.nan,34000]
}

# %%
data
# Out:
# {'Name': ['preeti', 'bob', 'Me', 'Eve', 'adu'],
#  'age': [23, 30, 35, nan, 20],
#  'dept': ['HR', 'IT', 'finace', 'It', 'HR'],
#  'sal': [23000, 45000, 70000, nan, 34000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Name   age    dept      sal
# 0  preeti  23.0      HR  23000.0
# 1     bob  30.0      IT  45000.0
# 2      Me  35.0  finace  70000.0
# 3     Eve   NaN      It      NaN
# 4     adu  20.0      HR  34000.0

# %%
df.head(2)
# Out:
#      Name   age dept      sal
# 0  preeti  23.0   HR  23000.0
# 1     bob  30.0   IT  45000.0

# %%
df.tail(3)
# Out:
#   Name   age    dept      sal
# 2   Me  35.0  finace  70000.0
# 3  Eve   NaN      It      NaN
# 4  adu  20.0      HR  34000.0

# %%
#iloc and loc
df.iloc[1:3]
# Out:
#   Name   age    dept      sal
# 1  bob  30.0      IT  45000.0
# 2   Me  35.0  finace  70000.0

# %%
df.loc[1:3,["age","dept"]]
# Out:
#     age    dept
# 1  30.0      IT
# 2  35.0  finace
# 3   NaN      It

# %%
df.loc[1:3,:2] #row , col
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7580\3456743092.py in <module>
# ----> 1 df.loc[1:3,:2] #row , col
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     959             if self._is_scalar_access(key):
#     960                 return self.obj._get_value(*key, takeable=self._takeable)
# --> 961             return self._getitem_tuple(key)
#     962         else:
#     963             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1147             return self._multi_take(tup)
#    1148
# -> 1149         return self._getitem_tuple_same_dim(tup)
#    1150
#    1151     def _get_label(self, label, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %%
df.iloc[1:3,:3] #row,col
# Out:
#   Name   age    dept
# 1  bob  30.0      IT
# 2   Me  35.0  finace

# %%
#for only one col

df["age"]
# Out:
# 0    23.0
# 1    30.0
# 2    35.0
# 3     NaN
# 4    20.0
# Name: age, dtype: float64

# %%
df[["age","Name"]]
# Out:
#     age    Name
# 0  23.0  preeti
# 1  30.0     bob
# 2  35.0      Me
# 3   NaN     Eve
# 4  20.0     adu

# %%
df.drop("age",axis=1)
# Out:
#      Name    dept      sal
# 0  preeti      HR  23000.0
# 1     bob      IT  45000.0
# 2      Me  finace  70000.0
# 3     Eve      It      NaN
# 4     adu      HR  34000.0

# %%
df #in original no change happen
# Out:
#      Name   age    dept      sal
# 0  preeti  23.0      HR  23000.0
# 1     bob  30.0      IT  45000.0
# 2      Me  35.0  finace  70000.0
# 3     Eve   NaN      It      NaN
# 4     adu  20.0      HR  34000.0

# %%
#if you want to change in origianl use inplace=True

df.drop('age',axis=1,inplace =True)

# %%
df
# Out:
#      Name    dept      sal
# 0  preeti      HR  23000.0
# 1     bob      IT  45000.0
# 2      Me  finace  70000.0
# 3     Eve      It      NaN
# 4     adu      HR  34000.0

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   dept    5 non-null      object
#  2   sal     4 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 248.0+ bytes

# %%
df.describe()
# Out:
#                 sal
# count      4.000000
# mean   43000.000000
# std    20116.328359
# min    23000.000000
# 25%    31250.000000
# 50%    39500.000000
# 75%    51250.000000
# max    70000.000000

# %%
d1 = {
    "name":["preeti","Riya","amit"],
    "age":[23,45,25],
    "city":["banglore","pune","belgaum"]
}

# %%
df = pd.DataFrame(d1)
df
# Out:
#      name  age      city
# 0  preeti   23  banglore
# 1    Riya   45      pune
# 2    amit   25   belgaum

# %%
df.head(3)
# Out:
#      name  age      city
# 0  preeti   23  banglore
# 1    Riya   45      pune
# 2    amit   25   belgaum

# %%
df.tail(2)
# Out:
#    name  age     city
# 1  Riya   45     pune
# 2  amit   25  belgaum

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   city    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.dtypes
# Out:
# name    object
# age      int64
# city    object
# dtype: object

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   31.000000
# std    12.165525
# min    23.000000
# 25%    24.000000
# 50%    25.000000
# 75%    35.000000
# max    45.000000
