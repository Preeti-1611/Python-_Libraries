# %%
import numpy as np
a = np.array([3,4,5])
b =np.array([6,7,8])

# %%
print(a+b)
# Out:
# [ 9 11 13]

# %%
#subtrcation
print(a-b)
# Out:
# [-3 -3 -3]

# %%
#division
print(a/b)
# Out:
# [0.5        0.57142857 0.625     ]

# %%
print(b//a)
# Out:
# [2 1 1]

# %%
#multi
print(a*b)
# Out:
# [18 28 40]

# %%
#moduls
print(b%a)
# Out:
# [0 3 3]

# %%
#exponents power
print(a**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9572\3514903773.py in <module>
#       1 #exponents power
# ----> 2 print(a**2)
#
# NameError: name 'a' is not defined
