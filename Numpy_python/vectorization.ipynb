# %%
# np.vectorize()


import numpy as np
arr = np.array([3,5,7,3,7,2,8])

# %%
def square(x):
    return x*x
vfunc = np.vectorize(square)

# %%
arr
# Out:
# array([3, 5, 7, 3, 7, 2, 8])

# %%
print(vfunc(arr))
# Out:
# [ 9 25 49  9 49  4 64]

# %%
import numpy as np
a = np.array([2,4,6,8])

res = a*2
print(res)
# Out:
# [ 4  8 12 16]

# %%
a>4
# Out:
# array([False, False,  True,  True])

# %%
a**2
# Out:
# array([ 4, 16, 36, 64])
