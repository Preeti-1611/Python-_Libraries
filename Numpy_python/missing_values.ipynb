# %%
#np.nan not a number
import numpy as np
a = np.array([12.,4.5,np.nan,3.0])
a
# Out:
# array([12. ,  4.5,  nan,  3. ])

# %%
# np.inf and -np.inf  positive and negative infinstes

# %%
# np.isnan
# np.isinf
# np.isfinite

# null values infinte values fnite values

# %%
print(np.isnan(a))
 np.isnan(a).sum()  # Count missing values
# Out:
# [False False  True False]
# 1

# %%
b = np.array([1,np.nan,np.inf,9,12.,9])
print(np.isinf(b))
# Out:
# [False False  True False False False]

# %%
import pandas as pd
s = pd.Series(['a',np.nan,1,np.nan,2])
s.notnull().sum()
# Out:
# 3
